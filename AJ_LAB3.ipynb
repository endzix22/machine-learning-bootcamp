# %% [markdown]
# <a href="https://colab.research.google.com/github/endzix22/machine-learning-bootcamp/blob/main/AJ_LAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Programu Operacyjnego Polska Cyfrowa na lata 2014-2020
# <hr>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <center>
#     <h1 style = "font-size:48px; font-weight:normal"><b>AI</b>-TECH</style></h1>
#     <br>
# <br>
# <br>
# <br>
#     <h1 style = "font-size:24px; font-weight:normal">SKRYPT DO LABORATORIUM</style></h1>
#     <h1 style = "font-size:24px"><b>Języki programowania dla sztucznej inteligencji</b></style></h1>
#
#
#
# </center>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#     </body>
#     </html>

# %% [markdown]
# ![FE_POPC_poziom_pl-1_rgb.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# <hr>

# %% [markdown]
# # 1. Opis ćwiczenia

# %% [markdown]
# #### Wymagania wstępne:
#
# Wymagania w odniesieniu do studenta:
#
# Właściwe przygotowanie się studenta do zajęć pozwoli na osiągnięcie celów ćwiczenia. Przed przystąpieniem do ćwiczenia student powinien:
#
# - powtórzyć wiedzę nabytą w czasie wykładów,
# - zapoznać się z instrukcją do ćwiczenia ilustrującą podstawowe zagadnienia z zakresu tematyki ćwiczenia.
#
# Dodatkowo wymagana jest od studenta:
#
# - podstawowa umiejętność programowania,
# - podstawowa znajomość języka Python.
#
#
#
# Wymagania w odniesieniu do stanowiska laboratoryjnego:
#
# Stanowisko laboratoryjne powinno być wyposażone w komputer z dostępem do sieci komputerowej oraz z następującymi zasobami:
#
# - przykładowe kody programów (załącznik),
# -	Python 3,
# -	pakiety NumPy, Matplotlib, OpenCV, Tensorflow, Keras, Pillow,
# -	Jupyter Notebook,
# -	inne: przeglądarka WWW.

# %% [markdown]
# #### Cele ćwiczenia:
#
# Celem ćwiczenia jest praktyczne przedstawienie wiedzy zdobytej podczas wykładów. Podczas realizacji ćwiczenia laboratoryjnego studenci zdobędą umiejętności w zakresie wizualizacji różnego typu danych oraz augmentacji danych, w szczególności obrazów.

# %% [markdown]
# #### Spodziewane efekty kształcenia ‐ umiejętności i kompetencje:
#
# Po zakończeniu ćwiczenia laboratoryjnego student będzie umiał wizualizować dane różnego typu (m.in. wykresy punktowe, obrazy). Zdobędzie także podstawową wiedzę w zakresie augmentacji danych – tworzenia własnych funkcji i klas do augmentacji oraz wykorzystania możliwości bibliotek programistycznych popularnych w dziedzinie uczenia maszynowego w ramach augmentacji danych.

# %% [markdown]
# #### Metody dydaktyczne:
#
# Na początku student realizuje zadania przykładowe, które prezentują poszczególne elementy pracy związane z wizualizacją różnego typu danych, w tym obrazów oraz augmentacją danych. W kolejnym kroku realizuje zadania według wytycznych, na podstawie zdobytych umiejętności i wiedzy. Kody źródłowe i wyniki wykonywanych programów student powinien umieszczać w dokumencie elektronicznym, który stanie się sprawozdaniem z ćwiczenia laboratoryjnego.
#
# Materiały wprowadzające i pomocnicze:
#
# - OpenCV – dokumentacja biblioteki https://docs.opencv.org/master/index.html,
# - Matplotlib – dokumentacja biblioteki https://matplotlib.org/stable/contents.html,
# - Numpy - dokumentacja biblioteki https://numpy.org/doc/,
# - Tensorflow – dokumentacja biblioteki https://www.tensorflow.org/api_docs,
# - Keras - dokumentacja biblioteki https://keras.io/api/,
# - Pillow - dokumentacja biblioteki https://pillow.readthedocs.io/en/stable/,
# - Python 3 - dokumentacja języka https://docs.python.org/3/.

# %% [markdown]
# #### Zasady oceniania/warunek zaliczenia ćwiczenia:
#
# Każde z realizowanych podczas ćwiczenia laboratoryjnego zadań będzie podlegało ocenie. W trakcie realizacji ćwiczenia, mogą zostać przydzielone dodatkowe zadania do realizacji. Maksymalna liczba punktów do zdobycia wynosi 12.

# %% [markdown]
# #### Wykaz literatury podstawowej do ćwiczenia:
#
#
# 1. Treści wykładowe do przedmiotu “Języki programowania dla sztucznej inteligencji”
#
# 2. M. Lutz, Python. Wprowadzenie. Wydanie V, O'Reilly, 2020
#
# 3. R. Johansson, Matematyczny Python. Obliczenia naukowe i analiza danych z użyciem NumPy, SciPy i Matplotlib, Helion/Apress, 2021
#
# 4. W. McKinney, Python w analizie danych. Przetwarzanie danych za pomocą pakietów Pandas i NumPy oraz środowiska IPython. Wydanie II, O'Reilly, 2018

# %% [markdown]
# # 2. Przebieg ćwiczenia

# %% [markdown]
# 1. Zapoznanie się z instrukcją laboratoryjną (przed ćwiczeniem)
# 2. Zadanie nr 1 - wizualizacja różnych typów danych (40 min.)
# 3. Zadanie nr 2 - augmentacja danych (40 min.)
# 4. Zadanie nr 2a - tworzenie klasy i funkcji do augmentacji danych (50 min.)
# 5. Przesłanie sprawozdania z zajęć (5 min.)

# %% [markdown]
# # 3. Wprowadzenie do ćwiczenia

# %% [markdown]
# Realizacja poszczególnych zadań będzie odbywała się zgodnie z przedstawionym opisem. Każde z zadań zostało opisane poniżej (oprócz zadania realizowanego samodzielnie przed przystąpieniem do realizacji ćwiczenia).

# %% [markdown]
# ## **Zadanie nr 1** - wizualizacja różnych typów danych
#
# > Podczas pracy z różnego rodzaju klasyfikatorami czy algorytmami, trzeba poradzić sobie z obsługą różnego typu danych - danymi tekstowymi, obrazami czy dźwiękami. Dostępne metody wizualizacji danych są różne, kilka przykładów zostanie przedstawione w poniższych ćwiczeniach.

# %% [markdown]
# **1a**. Wizualizacja danych z wykorzystaniem narzędzi *matplotlib*
#
# > Znaczna większość narzędzi znajduje się w podrzędnym modelu *pyplot*. Zazwyczaj importowane są one z wykorzystaniem aliasu *plt*.
#
# > Funkcja *plot* jest wykorzystywana najczęściej do rysowania punktów na wykresie. Domyślnie, rysuje linię między dwoma punktami (można również rysować linie między większą ilością punktów).
#
# Poniższy przykład ilustruje wykorzystanie funkcji *plot* wraz z funkcją *subplot* do narysowania dwóch wykresów prezentowanych na jednym rysunku.

# %%
import matplotlib.pyplot as plt
import numpy as np

# dane do pierwszego wykresu
x1 = np.array([0, 3, 7, 9])
y1 = np.array([5, 2, 15, 7])

# rysujemy pierwszy wykres - rysunek ma jeden wiersz, dwie kolumny;
plt.subplot(1, 2,1)
plt.plot(x1,y1)
# dodajemy tytuł wykresu
plt.title("PIERWSZY")

# dane do drugiego wykresu (jeśli nie zdefinujemy wartości dla osi x, 
# domyślnie zostaną im przypisane wartości 0,1,2, ... - w zależności od ilości elementów zdefiniowanych dla y)
y2 = np.array([10, 20, 30, 40])

# rysujemy drugi wykres
plt.subplot(1, 2, 2)
plt.plot(y2) #domyslnie x=0,1,2,3
# dodajemy tytuł wykresu
plt.title("DRUGI")

plt.show()

# %% [markdown]
# Stwórz sześć różnych wykresów i wyświetl je na jednym rysunku w konfiguracji trzech rzędów i dwóch kolumn. Opisz każdy z wykresów oraz dodaj główną nazwę dla wszystkich wykresów (*suptitle*). Dla każdego z wykresów użyj inny styl linii i kolor linii oraz wygląd markerów punktów charakterystycznych.
#
#
#
# > [Dokumentacja - *plot*](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot)

# %% [markdown]
# jeden duzy podpis nad wszystkimi: "subtitle"
# 6 różnych wykresów z podpisami +inny styl linii, kolor oraz wyglad markerow
# 3 rzedy, dwie kolumny.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random 
x=np.random.randint(200, size=10)
ys=[x**2,x%2,x*12,x/(x-1),x*x,x/(x+1)]
titles=["pierwszy","drugi","trzeci","czwarty","piąty","szósty"]
colors=["k","c","g","b","r","m"]
linestyles = ['-', '--', '-.', ':', '-', '--']
plt.figure(figsize=(12, 15), dpi=60).tight_layout()
for i in range(6):
    plt.subplot(3,2,i+1)
    plt.plot(x,ys[i], color=colors[i], linestyle=linestyles[i])
    plt.title(titles[i])
    plt.xlabel("x")
    plt.ylabel("y")
plt.suptitle("6 random plots")
plt.show()

# %% [markdown]
# **1b**. Wizualizacja danych - wykres punktowy
#
# > Jedna z podstawowych metod wizualizacji serii danych są wykresy punktowe. W pakiecie *Matplotlib* można łatwo stworzyć taki wykres wykorzystując metodę *scatter*, co pokazano na poniższym przykładzie.
#
#     Dane wykorzystane do stworzenia poniższego wykresu pochodzą z danych Głównego Urzędu Statystycznego.
#     Dotyczą one liczby zachorowań na gruźlicę oraz salmonellozę w latach 1999-2019.

# %%
import matplotlib.pyplot as plt

liczba_zachorowan_gruzlica = [12179, 11477,	10672,	10475,	10124,	9493,	9269,	8587,	8614,	8081,	8236,	7509,	8478,	7542,	7250, 6698,	6430,	6444,	5787,	5487,	5321]
liczba_zachorowan_salmonelloza = [23436,	22799,	19881,	20689, 16612,	15958,	16006,	13362,	11704,	9609,	8964,	9732,	8813,	8444,	7577, 8392,	8652,	10028,	10000,	9957,	9234]
zakres_lat = [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019] 


fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
# dodanie serii danych
ax.scatter(zakres_lat, liczba_zachorowan_gruzlica, color='g', label='gruźlica')
ax.scatter(zakres_lat, liczba_zachorowan_salmonelloza, color='y', label='salmonelloza')
# dodanie opisów osi, tytułu wykresu oraz legendy
ax.set_xlabel('Rok')
ax.set_ylabel('Liczba zachorowań')
ax.set_title('Zachorowania na gruźlicę i salmonellozę w latach 1999-2019')
ax.legend()
plt.show()

# %% [markdown]
# Stwórz własny wykres dla serii danych wygenerowanych losowo. Na osi Y wygeneruj 300 wartości z zakresu 0-300, a dla osi X stwórz dwie serie danych: pierwszą zawierającą 300 losowych elementów z zakresu 10-200, a drugą z wartościami z zakresu 300-450.

# %%
# tutaj umieść kod
import matplotlib.pyplot as plt
import random 

np.random.seed(42)
liczba_zachorowan_gruzlica = np.random.randint(10,201, size=300)
liczba_zachorowan_salmonelloza =np.random.randint(300,451, size=300)
zakres_lat = np.random.randint(0,301,size=300)

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
# dodanie serii danych
ax.scatter(zakres_lat, liczba_zachorowan_gruzlica, color='g', label='losowe')
ax.scatter(zakres_lat, liczba_zachorowan_salmonelloza, color='y', label='losowe')
# dodanie opisów osi, tytułu wykresu oraz legendy
ax.set_xlabel('losowe')
ax.set_ylabel('losowe')
ax.set_title('losowe')
ax.legend()
plt.show()

# %% [markdown]
# **1c**. Wizualizacja i operacje na obrazach
#
# > Wykorzystując bibliotekę *Pillow* do obsługi grafiki, można wczytać, modyfikować i wyświetlać pliki graficzne.
#
# Przeanalizuj poniższy przykład, który pokazuje jak wczytać i wyświetlić obraz oraz podstawowe informacje o nim, a także dokonać prostych operacji na wczytanym obrazie.

# %%
# zaimportowanie klasy Image z pakietu PIL 
from PIL import Image 

# stworzenie obiektu ze wskazaniem na obraz do wczytania
img = Image.open("/content/lab3_1.jpg")



#wyświetlenie obrazu
img


# wyświetlenie informacji o wczytanym obrazie - format, tryb i rozmiar obrazu 
format = img.format
rozmiar = img.size 
tryb = img.mode

print("Format: " + format + ", tryb: " + tryb + ", rozmiar: " + str(rozmiar))


#  obrócenie obrazu o 90 stopni
img_rotated = img.rotate(90)

img_rotated

# zmiana trybu na skalę szarości
img_grayscale = img.convert('L')

img_grayscale
# Out:
# Format: JPEG, tryb: RGB, rozmiar: (523, 389)
# <PIL.Image.Image image mode=L size=523x389 at 0x7F14F36AFE50>

# %% [markdown]
# Wykorzystując załączony przykład obrazu (*lab3_2.jpg*), sprawdź jaka jest jego szer0kość i wysokość. Następnie wytnij fragment obrazu. Z oryginalnego obrazu utwórz minaturę o wymiarach 150x150 pikseli i zapisz ją do pliku z rozszerzeniem .png.
#
# > [Dokumetacja modułu IMAGE](https://pillow.readthedocs.io/en/4.1.x/reference/Image.html)

# %%
#tutaj umieść kod
from PIL import Image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True 
img = Image.open("/content/lab3_2.jpg")
print("Wysokość obrazka: ", img.size[1], "\nSzerokość obrazka: ", img.size[0])
box_cut =(450, 450, 750, 750)
img_cut = img.crop(box_cut)
img_smaller = img.resize((150, 150))
img_smaller.save("/content/smaller_image.png")
img_smaller
# Out:
# Wysokość obrazka:  3648
# Szerokość obrazka:  2736
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F14F36917D0>

# %%
# zaimportowanie klasy Image z pakietu PIL 
from PIL import Image 
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
# stworzenie obiektu ze wskazaniem na obraz do wczytania
img = Image.open("/content/lab3_2.jpg")


#wyświetlenie obrazu
img
# wyświetlenie informacji o wczytanym obrazie - szerokosc wysokosc
tryb = img.mode
print( " ROZMIAR\n " +"szerokosc: " +str(rozmiar[0])+ " wysokosc: "+str(rozmiar[1]))


img_resize = img.resize((150, 150))
img_resize.save("/content/copy.png")

img_crop = img.crop((400, 350, 750, 750))
img_crop
# Out:
#  ROZMIAR
#  szerokosc: 523 wysokosc: 389
# <PIL.Image.Image image mode=RGB size=350x400 at 0x7F14F3640AD0>

# %%
img_resize
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F14F36A8710>

# %%
## Np przycinanie środka obrazu +zapis 
"""
img = Image.open("C:/Users/andzi/Downloads/języki/lab3_2.jpg")
def crop_center(pil_img, crop_width, crop_height):
    img_width, img_height = pil_img.size
    return pil_img.crop(((img_width - crop_width) // 2,
                         (img_height - crop_height) // 2,
                         (img_width + crop_width) // 2,
                         (img_height + crop_height) // 2))

im_new=crop_center(img,523,389)
im_new.save("C:/Users/andzi/Downloads/języki/copy2.png")
"""

# %%
#wyswietlenie obrazkow zpaisanych:
im_new
# Out:
# <PIL.Image.Image image mode=RGB size=523x389 at 0x1F191662E20>

# %%
img_resize
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x1F19176C880>

# %% [markdown]
# ## **Zadanie nr 2** - augmentacja danych
#
# > Augmentacja danych jest jedną z możliwości, która pozwala na zapobiegnięcie nadmiernemu dopasowaniu modelu. Tą technikę można wykorzystać do sztucznego zwiększenia danych - stworzenie danych zmodyfikowanych na podstawie już istniejących.
#
# > Do danych początkowych możemy wprowadzić różne zmiany. Dla obrazów mogą to być przekszatłcenia geometryczne lub zmiana przestrzeni kolorów, a dla danych tekstowych - tasowanie. Augmentacja daje wiele możliwości ze względu na możliwość używania wszystkich metod jednocześnie - pozwala to uzyskać wiele unikalnych próbek.

# %% [markdown]
# Augmentację danych można przeprowadzić na kilka sposobów, między innymi wykorzystując funkcje wbudowane w różne biblioteki. Inną możliwością jest stworzenie własnej funkcji, która z powodzeniem pozwoli na uzyskanie oczekiwanych efektów.
#
# Poniżej przedstawiony został przykład funkcji, która bazując na możliwościach jakie daje bibliteka OpenCV (obrót obrazu o zadany kąt z wykorzystaniem *getRotationMatrix2D* oraz *warpAffine*). Jako argumenty funkcja przyjmuje: obraz, który ma zostać poddany augmentacji oraz kąt o jaki obraz ma zostać obrócony.
#
# > [OpenCV - dokumentacja warpAffine ](https://docs.opencv.org/3.4/d4/d61/tutorial_warp_affine.html)
#
#
# Tak stworzona funkcja może być jedną z wielu funkcji wchodzących w skład klasy, która będzie odpowiedzialna za augmentację danych.

# %%
import cv2
def augment_rotation(img, angle=90):
    (h,w) = img.shape[:2] # wysokość i szerokość obrazu
    scale = 1.0
# macierz obrotu
    M = cv2.getRotationMatrix2D((w/2,h/2), angle, scale)
# obrót
    image = cv2.warpAffine(img,M,(w,h))
    return image

# %% [markdown]
# Sprawdźmy, jakie działanie ma stworzona powyżej funkcja, wykorzystując obraz *lab3_1.jpg*.

# %%
#wczytujemy obraz
import matplotlib.pyplot as plt
obraz = cv2.imread("/content/lab3_1.jpg")
obraz_obrocony = augment_rotation(img=obraz,angle=-30)
plt.imshow(obraz_obrocony)
plt.show()

# %% [markdown]
# Jak widzimy obraz został obrócony o zadany kąt, ale również obcięty.
#
# Wewnątrz funkcji *augment_rotation* został zdefiniowany parametr *scale*, który z powodzeniem mógłby być argumentem tej funkcji - wtedy jednocześnie można byłoby obracać i skalować obraz.

# %% [markdown]
# **2a**. Stwórz klasę o nazwie *ImageAugmentation*, a następnie utwórz w niej **trzy** funkcje pozwalające na augmentację danych (niech każda z funkcji ma inne zastosowanie, także inne od przedstawionego przykładu powyżej).
#
# Może to być na przykład: odwrócenie w pionie/poziomie, przesunięcie, dodanie szumu, zmiana rozmiaru obrazu, konwersja do skali szarości, zmiana jasności lub nasycenia.
#
# Do tworzenia funkcji wykorzystaj możliwości biblioteki OpenCV.
#
#
#
# > [Dokumentacja - OpenCV](https://docs.opencv.org/master/d6/d00/tutorial_py_root.html)

# %%
# tutaj umieść kod
class ImageAugmentation:
    def __init__(self, image):
        self.image = image
 
 ### I
    def crop(self, center, width, height):
        self.image=cv2.getRectSubPix(self.image, (width, height), center)
        return self

###II
    def rotate(self):
        self.image=cv2.rotate(self.image,cv2.ROTATE_180)
        return self

###III 
    def transopnse(self):
        self.image=cv2.transpose(self.image)
        return self

###IV
    def resize(self, dim = (100, 100)):
        self.image = cv2.resize(self.image, dim, interpolation = cv2.INTER_CUBIC)
        return self


    def show(self):
        plt.imshow(self.image)
        plt.show()
        return self

# %% [markdown]
# **2b**. Wykorzystując stworzone funkcje z klasy *ImageAugmentation*, zaprezentuj ich działanie stosując je pojedynczo oraz kaskadowo.

# %%
# tutaj umieść kod
im = cv2.imread('/content/lab3_1.jpg')
aug = ImageAugmentation(im)

# %%
#I opcja 
aug = ImageAugmentation(im)
aug.rotate().show()

# %%
##II opcja 
aug=ImageAugmentation(im)
aug.transopnse().show()

# %%
## III
aug = ImageAugmentation(im)
aug.crop(center=(190, 220), width=300, height=200).show()

# %%
#IV opcja 
aug = ImageAugmentation(im)
aug.resize().show()

# %%
##kaskadowe wywolanie 
aug=ImageAugmentation(im)
cascade=aug.crop(center=(190,220),width=300,height=200).rotate().transopnse().resize()
cascade.show()

# %% [markdown]
# > Biblioteka *Tensorflow* jest szczególnie wykorzystywana w dziedzinie uczenia maszynowego oraz uczenia głębokiego. Jedną z cech szczególnych jest wykorzystanie diagramów przepływu danych.
#
# > Keras jest to API do uczenia głębokiego napisane w języku Python. Działa na platformie Tensorflow. Jego zadaniem jest szybkie i łatwe tworzenie modeli oraz praca z nimi.
#
# Tak jak zostało wspomniane wcześniej, augmentacja danych może zostać przeprowadzona z wykorzystaniem funkcji istniejących już w bibliotekach uczenia maszynowego.

# %% [markdown]
# **2c**. Augmentacja danych z wykorzystaniem framework'ów Tensorflow i Keras.
#
# Jedną z możliwości jest wykorzystanie *tf.image* do stworzenia własnej funkcji rozszerzającej dane.
#
# Poniżej zaprezentowano przykład funkcji, która odwraca obraz wzdłuż pierwszego wymiaru oraz wyświetla obraz oryginalny i nowostworzony (przy wykorzystaniu tej funkcji mamy 50% szans, że nasz obraz zostanie odwrócony), a także przykład funkcji konwertującej obraz do skali szarości i jednocześnie obracająca obraz o 90 stopni.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def flip_and_visualize(original):
    fig = plt.figure()
    plt.subplot(1,2,1)
    plt.title('Obraz oryginalny')
    plt.imshow(original)

    plt.subplot(1,2,2)
    plt.title('Obraz obrócony')    
    flipped = tf.image.random_flip_up_down(image)
    plt.imshow(flipped)

image = mpimg.imread('/content/lab3_1.jpg')

flip_and_visualize(image)

# %%
def saturation_and_visualize(original):
    fig = plt.figure()
    plt.subplot(1,2,1)
    plt.title('Obraz oryginalny')
    plt.imshow(original)

    plt.subplot(1,2,2)
    plt.title('Obraz obrócony o 90 stopni')

    saturation = tf.image.rot90(original)
    plt.imshow(saturation)

image = mpimg.imread('/content/lab3_1.jpg')

saturation_and_visualize(image)

# %% [markdown]
# Wykorzystując możliwości *tf.image*, przeprowadź dwa eksperymenty z różnymi możliwościami przetwarzania obrazów (wykorzystanie minimum dwóch różnych możliwości).
#
# > [Dokumentacja - tf.image ](https://www.tensorflow.org/api_docs/python/tf/image)

# %%
#I opcja 
def image_transponse(original):
    fig = plt.figure()
    plt.subplot(1,2,1)
    plt.title('Obraz oryginalny')
    plt.imshow(original)

    plt.subplot(1,2,2)
    plt.title('Obraz transponowany')    
    f=tf.image.transpose(image)
    plt.imshow(f)

image = mpimg.imread('/content/lab3_1.jpg')

image_transponse(image)

# %%
#II opcja 

def adjust_brightness(original):
    fig = plt.figure()
    plt.subplot(1,2,1)
    plt.title('Obraz oryginalny')
    plt.imshow(original)

    plt.subplot(1,2,2)
    plt.title('Obraz rozjaśniony')

    s = tf.image.adjust_brightness(image,delta=0.7)
    plt.imshow(s)

image = mpimg.imread('/content/lab3_1.jpg')

adjust_brightness(image)

# %% [markdown]
# **2d**. Augmentacja danych może zostać również przeprowadzona z wykorzystaniem biblioteki Keras, w której znajdują się różne warstwy przetwarzania wstępnego.
# Poniższy przykład ilustruje wykorzystanie dwóch warstw - losowego powiększenia oraz przeskalowania obrazu.
#
# > Zbiór danych *rock_paper_scissors* zawiera prawie 3000 obrazów rąk osób grających w kamień, papier, nożyczki.

# %%
from tensorflow.keras import layers
#załadowania zbioru danych i podział na zbiory - treningowy, walidacyjny i testowy
(train_leaves_ds, val_leaves_ds, test_leaves_ds), metadata = tfds.load(
    'rock_paper_scissors',
    split=['train[:85%]', 'train[85%:95%]', 'train[95%:]'],
    with_info=True,
    as_supervised=True
)

# pobranie jednego obrazu ze zbioru treningowego 
image, label = next(iter(train_leaves_ds))

#dodanie obrazu do batcha
image = tf.expand_dims(image, 0)

#docelowy rozmiar obrazu
IMG_SIZE=250

resize_zoom_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  layers.experimental.preprocessing.RandomZoom(0.5),
  layers.experimental.preprocessing.Rescaling(1./255) #standaryzacja wartości pikseli 0-1
])

image_after_augmentation = resize_zoom_and_rescale(image)

plt.imshow(image_after_augmentation[0])
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/rock_paper_scissors/3.0.0.incomplete9PY9M4/rock_paper_scissors-train.tfrecord
#   0%|          | 0/2520 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/rock_paper_scissors/3.0.0.incomplete9PY9M4/rock_paper_scissors-test.tfrecord
#   0%|          | 0/372 [00:00<?, ? examples/s]
# Dataset rock_paper_scissors downloaded and prepared to /root/tensorflow_datasets/rock_paper_scissors/3.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# Przeanalizuj powyższy kod i uruchom go kilka razy - zobacz, jak zmienia się wyświetlany obraz po augmentacji.
# Stwórz własną funkcję do augmentacji obrazu wykorzystując inne warstwy dostępne w pakiecie Keras. Wyświetl wyniki działania stworzonej funkcji.

# %% [markdown]
# Augmentacja danych-technika pozwalajajaca na zwiekszenie zbioru treningowego przez odpowiednie przeksztalcenie danych wejsciowych. Technika bardzo przydatna zwlaszcza gdy nie mamy wystarczajacej ilosci danych do wytrenowania sieci. Wykorzystamy ta technike do trenowania problemow zwiazanych z przetwarzaniem obrazu.

# %%
from tensorflow.keras import layers
#załadowania zbioru danych i podział na zbiory - treningowy, walidacyjny i testowy
(train_leaves_ds, val_leaves_ds, test_leaves_ds), metadata = tfds.load(
    'plant_village',
    split=['train[:85%]', 'train[85%:95%]', 'train[95%:]'],
    with_info=True,
    as_supervised=True
)

# pobranie jednego obrazu ze zbioru treningowego 
image, label = next(iter(train_leaves_ds))

#dodanie obrazu do batcha
image = tf.expand_dims(image, 0)

#docelowy rozmiar obrazu
IMG_SIZE=256

augmentation = tf.keras.Sequential([
 layers.experimental.preprocessing.CenterCrop(IMG_SIZE, IMG_SIZE),
#zwraca środkowe ucięcie partii obrazów
 layers.experimental.preprocessing.RandomContrast([0.7, 1.3], seed=None),#Randomowe dodanie kontrastu
 layers.experimental.preprocessing.RandomZoom(0.5),
 layers.experimental.preprocessing.Rescaling(1./255) #standaryzacja

])


image_after_augmentation = augmentation(image)

plt.imshow(image_after_augmentation[0])
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/plant_village/1.0.2.incompleteKB3L8G/plant_village-train.tfrecord
#   0%|          | 0/54303 [00:00<?, ? examples/s]
# Dataset plant_village downloaded and prepared to /root/tensorflow_datasets/plant_village/1.0.2. Subsequent calls will reuse this data.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 4. Forma i zawartość sprawozdania

# %% [markdown]
# Sprawozdanie powinno zawierać kopie ekranu stworzonych kodów i wyników ich działania dla zadań, które w instrukcji zostały oznaczone kolorem zielonym oraz stosowne komentarze, jeśli zadanie tego wymaga. Dokument powinien zostać przesłany na serwer wskazany przez prowadzącego ćwiczenie w formacie PDF.

# %% [markdown]
# # Dodatki

# %% [markdown]
# Załącznik 1: Instrukcja wraz z wykonywalnymi kodami programów w formie pliku Jupyter Notebook
#
# Załącznik 2: Zestaw obrazów: **lab3_1.jpg**, **lab3_2.jpg**

# %% [markdown]
# ![FE_POPC_poziom_pl-1_rgb.jpg](data:image/jpeg;base64,...)
